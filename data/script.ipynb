# %%
import pandas as pd
import math

# %%
df = pd.read_csv('./pollution.csv')

# %%
df
# Out:
#                Country                                   Economic status1  \
# 0              Albania                                                LMI
# 1             Algeria8                                                UMI
# 2               Angola                                                LMI
# 3             Anguilla                                                HIC
# 4    Antigua & Barbuda                                                HIC
# ..                 ...                                                ...
# 197                NaN  4 - Bold data were taken directly from World B...
# 198                NaN  5 - Using a model developed for this study (se...
# 199                NaN              6 - From U.S. national litter study22
# 200                NaN                              7 - Calculated values
# 201                NaN  8 - Economic status changed from 2005 to 20106...
#
#     Coastal population2  Waste generation rate [kg/person/day]3  \
# ...

# %%
df = pd.read_csv('./pollution.csv', usecols=[0, 5, 8])
df
# Out:
#                Country  % Inadequately managed waste5  \
# 0              Albania                           45.0
# 1             Algeria8                           58.0
# 2               Angola                           71.0
# 3             Anguilla                            2.0
# 4    Antigua & Barbuda                            6.0
# ..                 ...                            ...
# 197                NaN                            NaN
# 198                NaN                            NaN
# 199                NaN                            NaN
# 200                NaN                            NaN
# 201                NaN                            NaN
#
#     Plastic waste generation [kg/day]7
# 0                              174,392
# 1                            2,374,214
# 2                              235,589
# 3                                3,654
# 4                               43,933
# ..                                 ...
# ...

# %%
df = df.rename(columns={'Plastic waste generation [kg/day]7': 'Plastic_Waste','% Inadequately managed waste5':'Inadequately_Managed'})
df
# Out:
#                Country  Inadequately_Managed Plastic_Waste
# 0              Albania                  45.0       174,392
# 1             Algeria8                  58.0     2,374,214
# 2               Angola                  71.0       235,589
# 3             Anguilla                   2.0         3,654
# 4    Antigua & Barbuda                   6.0        43,933
# ..                 ...                   ...           ...
# 197                NaN                   NaN           NaN
# 198                NaN                   NaN           NaN
# 199                NaN                   NaN           NaN
# 200                NaN                   NaN           NaN
# 201                NaN                   NaN           NaN
#
# [202 rows x 3 columns]

# %%
df.shape
# Out:
# (202, 3)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (192, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 192 entries, 0 to 191
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Country               192 non-null    object
#  1   Inadequately_Managed  192 non-null    float64
#  2   Plastic_Waste         192 non-null    object
# dtypes: float64(1), object(2)
# memory usage: 6.0+ KB

# %%
gdp_df = pd.read_csv('./original-gdp.csv')
gdp_df
# Out:
#                    Country    1999     2000     2001    2002    2003    2004  \
# 0    Afghanistan, Rep. of.       0        0        0   4.084   4.585   5.971
# 1                  Albania   3.444    3.695    4.096   4.456     5.6   7.452
# 2                  Algeria  48.845   54.749   55.181  57.053  68.013  85.016
# 3                   Angola   6.153    9.135    8.936  11.386  13.956    19.8
# 4      Antigua and Barbuda   0.652    0.678     0.71   0.718   0.754   0.818
# ..                     ...     ...      ...      ...     ...     ...     ...
# 175              Venezuela  97.977  117.153  122.872  92.889  83.442   112.8
# 176                Vietnam  28.684   31.196   32.504  35.148   39.63  45.548
# 177     Yemen, Republic of    7.53    9.561    9.533   9.985  11.869  13.565
# 178                 Zambia   3.132    3.238     3.64   3.775   4.326    5.44
# 179               Zimbabwe   5.963    8.136   12.883  30.856  10.515     4.7
#
# ...

# %%
gdp_df = pd.read_csv('./original-gdp.csv',usecols=[0, 11])
gdp_df
# Out:
#                    Country     2015
# 0    Afghanistan, Rep. of.        0
# 1                  Albania   11.591
# 2                  Algeria  175.077
# 3                   Angola  102.011
# 4      Antigua and Barbuda    1.285
# ..                     ...      ...
# 175              Venezuela  131.855
# 176                Vietnam  198.805
# 177     Yemen, Republic of        0
# 178                 Zambia   24.466
# 179               Zimbabwe   13.905
#
# [180 rows x 2 columns]

# %%
merge_df = pd.merge(df, gdp_df, on='Country')
merge_df
# Out:
#                   Country  Inadequately_Managed Plastic_Waste       2015
# 0                 Albania                  45.0       174,392     11.591
# 1                  Angola                  71.0       235,589    102.011
# 2               Argentina                  12.0     3,000,178    578.705
# 3               Australia                   0.0     1,902,591   1,240.80
# 4                 Bahrain                  10.0        97,743     30.914
# ..                    ...                   ...           ...        ...
# 100               Ukraine                  49.0       696,983     90.138
# 101  United Arab Emirates                   0.0       400,371    339.085
# 102        United Kingdom                   0.0     9,253,293   2,864.90
# 103         United States                   0.0    37,729,383  17,968.20
# 104               Vanuatu                  81.0        73,933      0.771
#
# [105 rows x 4 columns]

# %%
merge_df.to_csv('./output.csv', index=False)
